# %%
# !pip install numpy

# %%
# !pip install matplotlib

# %%
# !pip install opencv-python

# %%
# !pip list

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread("D:\DS\Image Smoothening\Data\Img1 (2).jpeg")
plt.imshow(img)

# %%
kernel = np.ones((5,5),np.float32)/25
dst = cv.filter2D(img, -1, kernel)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]),plt.yticks([])
plt.show
plt.subplot(122),plt.imshow(dst),plt.title('Smoothened')
plt.xticks([]),plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
grayimg = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(grayimg)

# %%
image = img
plt.imshow(image)

# %%
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
plt.imshow(image)

# %%
kernel = np.ones((5,5),np.float32)/25
dst = cv.filter2D(image, -1, kernel)
plt.imshow(dst)

# %%
pixel_vals = image.reshape((-1,3))
pixel_vals = np.float32(pixel_vals)
criteria = (cv.TERM_CRITERIA_EPS+cv.TERM_CRITERIA_MAX_ITER, 100, 0.85)
k = 2
retval,labels, centers = cv.kmeans(pixel_vals, k, None, criteria, 10, cv.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
final_metadata = centers[labels.flatten()]
final_image = final_metadata.reshape((image.shape))
plt.imshow(final_image)

# %%
#dst = cv.filter2D(final_image, -1, kernel)
#plt.imshow(dst)

# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in d:\ds\image smoothening\imsmoothsys\lib\site-packages (0.3.9)
# Requirement already satisfied: packaging>=21.3 in d:\ds\image smoothening\imsmoothsys\lib\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: Pillow>=8.0.0 in d:\ds\image smoothening\imsmoothsys\lib\site-packages (from pytesseract) (9.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\ds\image smoothening\imsmoothsys\lib\site-packages (from packaging>=21.3->pytesseract) (3.0.7)

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
print(pytesseract.image_to_string(final_image))
# Out:
# TNT CS HU)

# %%
kernel = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])
sharp_image = cv.filter2D(src = final_image, ddepth = -1, kernel = kernel)
plt.imshow(sharp_image)

# %%
print(pytesseract.image_to_string(sharp_image))
# Out:
# TIN 67 CS 2A)

# %%
print(pytesseract.image_to_string(dst))
# Out:
# 4 7 CS Tin)
